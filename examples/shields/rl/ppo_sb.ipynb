# %% [markdown]
# ## Example how to combine shielding with stable baselines contrib maskable ppo algorithm.

# %%
from sb3_contrib import MaskablePPO
from sb3_contrib.common.maskable.evaluation import evaluate_policy
from sb3_contrib.common.maskable.policies import MaskableActorCriticPolicy
from sb3_contrib.common.wrappers import ActionMasker
from stable_baselines3.common.callbacks import BaseCallback

import gymnasium as gym

from shieldhandlers import MiniGridShieldHandler, create_shield_query
from wrappers import MiniGridSbShieldingWrapper
# Out:
# pygame 2.5.1 (SDL 2.28.2, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2023-09-08 10:00:46.717621: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-08 10:00:47.771352: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       5 from stable_baselines3.common.callbacks import BaseCallback
#       7 import gymnasium as gym
# ----> 9 from examples.shields.rl.shieldhandlers import MiniGridShieldHandler, create_shield_query
#      10 from examples.shields.rl.wrappers import MiniGridSbShieldingWrapper
#
# ModuleNotFoundError: No module named 'examples'

# %%
def mask_fn(env: gym.Env):
    return env.create_action_mask()

# %%
shield_creator = MiniGridShieldHandler("grid.txt", "./main", "grid.prism", "Pmax=? [G !\"AgentIsInLavaAndNotDone\"]")

env = gym.make("MiniGrid-LavaCrossingS9N1-v0", render_mode="rgb_array")
env = MiniGridSbShieldingWrapper(env, shield_creator=shield_creator, shield_query_creator=create_shield_query, mask_actions=True)
env = ActionMasker(env, mask_fn)
model = MaskablePPO(MaskableActorCriticPolicy, env, verbose=1)


model.learn(10_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR            WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WGVR  VRVRVRVRVRWG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG            GGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR            WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VRGGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR            WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG  VRVRVRVRVRVRWG
# Reading   :	WG            GGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR            WG
# Reading   :	WGVRVRVR  VRVRVRWG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG            GGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR        VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG            GGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR            WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WGVRVRVR  VRVRVRWG
# Reading   :	WG            GGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR        VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG          VR  WG
# Reading   :	WG              WG
# Reading   :	WG          VRGGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR            WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WGVRVRVRVRVRVR  WG
# Reading   :	WG            GGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
#
# Write to file Grid.shield.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | 0.157    |
# | time/              |          |
# |    fps             | 165      |
# |    iterations      | 1        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2048     |
# ---------------------------------
#
# Reading   :	WGWGWGWGWGWGWGWGWG
# Reading   :	WGXR            WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WGVRVRVRVRVRVR  WG
# Reading   :	WG              WG
# Reading   :	WG              WG
# Reading   :	WG            GGWG
# Reading   :	WGWGWGWGWGWGWGWGWG
# Background:	WGWGWGWGWGWGWGWGWG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WG              WG
# Background:	WGWGWGWGWGWGWGWGWG
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       5 env = ActionMasker(env, mask_fn)
#       6 model = MaskablePPO(MaskableActorCriticPolicy, env, verbose=1)
# ----> 9 model.learn(10_000)
#
# File ~/Documents/Projects/tempestpy/env/lib/python3.10/site-packages/sb3_contrib/ppo_mask/ppo_mask.py:526, in MaskablePPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, use_masking, progress_bar)
#     523 callback.on_training_start(locals(), globals())
#     525 while self.num_timesteps < total_timesteps:
# --> 526     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, self.n_steps, use_masking)
#     528     if continue_training is False:
#     529         break
#
# File ~/Documents/Projects/tempestpy/env/lib/python3.10/site-packages/sb3_contrib/ppo_mask/ppo_mask.py:306, in MaskablePPO.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps, use_masking)
#     303     actions, values, log_probs = self.policy(obs_tensor, action_masks=action_masks)
#     305 actions = actions.cpu().numpy()
# --> 306 new_obs, rewards, dones, infos = env.step(actions)
#     308 self.num_timesteps += env.num_envs
#     310 # Give access to local variables
#
# File ~/Documents/Projects/tempestpy/env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~/Documents/Projects/tempestpy/env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:95, in VecTransposeImage.step_wait(self)
#      94 def step_wait(self) -> VecEnvStepReturn:
# ---> 95     observations, rewards, dones, infos = self.venv.step_wait()
#      97     # Transpose the terminal observations
#      98     for idx, done in enumerate(dones):
#
# File ~/Documents/Projects/tempestpy/env/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:70, in DummyVecEnv.step_wait(self)
#      67     if self.buf_dones[env_idx]:
#      68         # save final observation where user can get it, then reset
#      69         self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 70         obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      71     self._save_obs(env_idx, obs)
#      72 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~/Documents/Projects/tempestpy/env/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:83, in Monitor.reset(self, **kwargs)
#      81         raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82     self.current_reset_info[key] = value
# ---> 83 return self.env.reset(**kwargs)
#
# File ~/Documents/Projects/tempestpy/env/lib/python3.10/site-packages/gymnasium/core.py:414, in Wrapper.reset(self, seed, options)
#     410 def reset(
#     411     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     412 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     413     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 414     return self.env.reset(seed=seed, options=options)
#
# File ~/Documents/Projects/tempestpy/examples/shields/rl/Wrappers.py:222, in MiniGridSbShieldingWrapper.reset(self, seed, options)
#     219 obs, infos = self.env.reset(seed=seed, options=options)
#     221 keys = extract_keys(self.env)
# --> 222 shield = self.shield_creator.create_shield(env=self.env)
#     224 self.keys = keys
#     225 self.shield = shield
#
# File ~/Documents/Projects/tempestpy/examples/shields/rl/ShieldHandlers.py:82, in MiniGridShieldHandler.create_shield(self, **kwargs)
#      79 self.__export_grid_to_text(env)
#      80 self.__create_prism()
# ---> 82 return self.__create_shield_dict()
#
# File ~/Documents/Projects/tempestpy/examples/shields/rl/ShieldHandlers.py:66, in MiniGridShieldHandler.__create_shield_dict(self)
#      64 choice = shield_scheduler.get_choice(stateID)
#      65 choices = choice.choice_map
# ---> 66 state_valuation = model.state_valuations.get_string(stateID)
#      68 actions_to_be_executed = [(choice[1] ,model.choice_labeling.get_labels_of_choice(model.get_choice_index(stateID, choice[1]))) for choice in choices]
#      70 action_dictionary[state_valuation] = actions_to_be_executed
#
# KeyboardInterrupt:
